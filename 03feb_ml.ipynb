# %% [markdown]
# <a href="https://colab.research.google.com/github/JatinSinghalx/machine-learning/blob/main/03feb_ml.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Lab 4 (3rd Feb 2026) Linear Regression**

# %%
import numpy as np
x= np.array([1,3,5,7,8,9,10,15])
y =np.array([10,20,30,40,50,60,70,80])

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

print(Pearson_correlation(x,y))
print(Pearson_correlation(x,x))
print(Pearson_correlation(y,y))
print(Pearson_correlation(y,x))

#It is strong corelation because it is close to 1
# Out:
# 0.974894414261588
# 1.0
# 1.0
# 0.974894414261588

# %%
x1= np.array([1, 3, 5, 7, 8, 9, 10, 15])
y1= np.array([80,70,60,50,40,30,20,10])

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

# strong correlation
print(Pearson_correlation(x1,y1))
print(Pearson_correlation(x1,x1))
print(Pearson_correlation(y1,y1))
print(Pearson_correlation(y1,x1))
# Out:
# -0.974894414261588
# 1.0
# 1.0
# -0.974894414261588

# %%
x2= np.array([1,4,2,5,3,6,9,6,4,5])
y2= np.array([20,43,53,26,41,67,84,77,43,32])

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

# strong correlation
print(Pearson_correlation(x1,y1))
print(Pearson_correlation(x1,x1))
print(Pearson_correlation(y1,y1))
print(Pearson_correlation(y1,x1))
# Out:
# 0.7200034702381953
# 1.0
# 1.0
# 0.7200034702381953

# %%
x3= np.array([1,4,2,5,3,6,9,6,4,5])
y3= np.array([20,43,53,26,41,67,84,77,43,32])

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

# strong correlation
print(Pearson_correlation(x3,y3))
print(Pearson_correlation(x3,x3))
print(Pearson_correlation(y3,y3))
print(Pearson_correlation(y3,x3))

# %%
df= pd.read_csv('insurance.csv')
x4= np.array(df.age)
y4= np.array(df.bmi)

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

# strong correlation
print(Pearson_correlation(x4,y4))
print(Pearson_correlation(x4,x4))

#age with bmi
# Out:
# 0.10927188154853491
# 1.0

# %%
df= pd.read_csv('insurance.csv')
x4= np.array(df.age)
y4= np.array(df.children)

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

# strong correlation
print(Pearson_correlation(x4,y4))
print(Pearson_correlation(x4,x4))

#age with children
# Out:
# 0.04246899855884949
# 1.0

# %%
df= pd.read_csv('insurance.csv')
x4= np.array(df.charges)
y4= np.array(df.children)

def Pearson_correlation(X,Y):
    if len(X)==len(Y):
        Sum_xy = sum((X-X.mean())*(Y-Y.mean()))
        Sum_x_squared = sum((X-X.mean())**2)
        Sum_y_squared = sum((Y-Y.mean())**2)
        corr = Sum_xy / np.sqrt(Sum_x_squared * Sum_y_squared)
    return corr

# strong correlation
print(Pearson_correlation(x4,y4))
print(Pearson_correlation(x4,x4))

#charges with children
# Out:
# 0.0679982268479051
# 1.0

# %%
# Find the pearson correlation matrix
df= pd.read_csv('insurance2.csv')

corre = df.corr(method = 'pearson')
print(corre)
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000
